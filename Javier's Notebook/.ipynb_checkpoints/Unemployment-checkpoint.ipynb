# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
csv_file = os.path.join("..", "data", "state_unemployment.csv")
state_unemployment_df = pd.read_csv(csv_file)
state_unemployment_df.head()
# Out:
#         State  Oct 2010  Nov 2010  Dec 2010  Jan 2011  Feb 2011  Mar 2011  \
# 0     Alabama      10.1      10.2      10.3      10.2      10.2      10.1
# 1      Alaska       7.8       7.8       7.8       7.8       7.7       7.7
# 2     Arizona      10.1      10.0       9.9       9.8       9.7       9.7
# 3    Arkansas       8.3       8.3       8.4       8.5       8.5       8.5
# 4  California      12.3      12.3      12.2      12.1      12.0      11.9
#
#    Apr 2011  May 2011  Jun 2011  ...  Feb 2020  Mar 2020  Apr 2020  May 2020  \
# 0      10.0      10.0      10.0  ...       2.7       3.0      13.8       9.6
# 1       7.6       7.6       7.5  ...       5.8       5.2      13.5      12.7
# 2       9.7       9.7       9.7  ...       4.5       6.1      13.4       9.0
# 3       8.5       8.5       8.4  ...       3.5       5.0      10.8       9.6
# 4      11.8      11.8      11.8  ...       3.9       5.5      16.4      16.4
#
# ...

# %%
pg_user = 'postgres'
pg_password = 'brassclaw1'
db_name = 'unemployment_db'

connection_string = f"{pg_user}:{pg_password}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['states']

# %%
state_unemployment_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)
